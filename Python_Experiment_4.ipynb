# %% [markdown]
# <a href="https://colab.research.google.com/github/23yash06-source/python/blob/main/Python_Experiment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# question 1

# %%
# Write a program to count and display the number of capital letters in a given string.
s = input("enter a string")
count = 0
for i in s:
  if i.isupper():
    count +=1

print("No. of uppercase characters :",count)
# Out:
# enter a stringYAsh
# No. of uppercase characters : 2

# %% [markdown]
# question 2

# %%
# Count total number of vowels in a given string
s = input("Enter a string :")
vowels = "aeiouAEIOU"
count = 0

for i in s:
  if i in vowels:
    count += 1

print("no of uppercase characters :",count)
# Out:
# Enter a string :YaSh
# no of uppercase characters : 1

# %% [markdown]
# question 3

# %%
# Input a sentence and print words in separate lines.
sentence = input("Enter a sentence: ")

words = sentence.split()

for word in words:
    print(word)
# Out:
# Enter a sentence: yash is
# yash
# is

# %% [markdown]
# question 4

# %%
# 4.	WAP to enter a string and a substring. You have to print the number of times that the substring occurs in the given string. String traversal will take place from left to right, not from right to left.
string_main = input("Enter a string : ")
sub_string = input("Enter a substring : ")

count = 0
start = 0

while True:
    pos = string_main.find(sub_string, start)
    if pos == -1:
        break
    count = count + 1
    start = pos + 1

print("No. of occurrences :", count)
# Out:
# Enter a string : yash is
# Enter a substring :  good
# No. of occurrences : 0

# %% [markdown]
# question 5

# %%
# 5.	Given a string containing both upper and lower case alphabets. Write a Python program to count the number of occurrences of each alphabet (case insensitive) and display the same
s = input("Enter a string : ")
s = s.upper()

count = {}

for ch in s:
    if ch.isalpha():
        count[ch] = count.get(ch, 0) + 1

for key in sorted(count):
    print(f"{count[key]}{key}")
# Out:
# Enter a string : abhinav
# 2A
# 1B
# 1H
# 1I
# 1N
# 1V

# %% [markdown]
# question 6

# %%
# 6.	Program to count number of unique words in a given sentence using sets.
sentence = input("Enter a sentence : ")

words = sentence.split()

unique_words = set(words)

count = len(unique_words)

print("No. of unique words :", count)
# Out:
# Enter a sentence : Hello I am artificial intelligence equipped robo
# No. of unique words : 7

# %% [markdown]
# Question. 7 Create 2 sets s1 and s2 of n fruits each by taking input from user and find:
# a) Fruits which are in both sets s1 and s2
# b) Fruits only in s1 but not in s2
# c) Count of all fruits from s1 and s2

# %%
n = int(input("Enter number of fruits in each set: "))

s1 = set()
s2 = set()

print("\nEnter fruits for set s1:")
for i in range(n):
    fruit = input()
    s1.add(fruit)

print("\nEnter fruits for set s2:")
for i in range(n):
    fruit = input()
    s2.add(fruit)

# a) Fruits in both sets
common_fruits = s1 & s2

# b) Fruits only in s1 but not in s2
only_s1 = s1 - s2

# c) Count of all fruits from s1 and s2
all_fruits = s1 | s2
count_all = len(all_fruits)

print("\nFruits in both s1 and s2:", common_fruits)
print("Fruits only in s1 but not in s2:", only_s1)
print("Count of all fruits from s1 and s2:", count_all)
# Out:
# Enter number of fruits in each set: 5
#
# Enter fruits for set s1:
# orange
# pineapple
# apple
# papaya
# grapes
#
# Enter fruits for set s2:
# p
# r
# e
# e
# w
#
# Fruits in both s1 and s2: set()
# Fruits only in s1 but not in s2: {'orange ', 'papaya', 'apple', 'grapes', 'pineapple'}
# Count of all fruits from s1 and s2: 9

# %% [markdown]
# question 8

# %%
# 8.	Take two sets and apply various set operations on them :
# S1 = {Red ,yellow, orange , blue }
# S2 = {violet, blue , purple}
S1 = {"Red", "yellow", "orange", "blue"}
S2 = {"violet", "blue", "purple"}

print(S1 | S2)   # Union
print(S1 & S2)   # Intersection
print(S1 - S2)   # Difference
print(S1 ^ S2)   # Symmetric Difference
# Out:
# {'blue', 'Red', 'purple', 'yellow', 'violet', 'orange'}
# {'blue'}
# {'yellow', 'orange', 'Red'}
# {'Red', 'yellow', 'violet', 'orange', 'purple'}
