# %% [markdown]
# <a href="https://colab.research.google.com/github/23yash06-source/python/blob/main/Python_Experiment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Question 1

# %%
# 1.	Scan n values in range 0-3 and print the number of times each value has occurred.
n = int(input("Enter a number :"))
values = []
for i in range(1, n):
  val = int(input("Enter a number (0-3) :"))
  values.append(val)

for i in range(4):
  print(f"{i} occured {values.count(i)} times")
# Out:
# Enter a number :6
# Enter a number (0-3) :1
# Enter a number (0-3) :2
# Enter a number (0-3) :3
# Enter a number (0-3) :2
# Enter a number (0-3) :1
# 0 occured 0 times
# 1 occured 2 times
# 2 occured 2 times
# 3 occured 1 times

# %%
print(values)
# Out:
# [1, 2, 3, 2, 1]

# %% [markdown]
# Question 2

# %%
# 2.	Create a tuple to store n numeric values and find average of all values
n = int(input("Enter number of elements: "))
values = ()

for i in range(n):
    num = int(input("Enter value: "))
    values = values + (num,)

average = sum(values) / n

print("Tuple:", values)
print("Average of values:", average)
# Out:
# Enter number of elements: 4
# Enter value: 10
# Enter value: 20
# Enter value: 30
# Enter value: 40
# Tuple: (10, 20, 30, 40)
# Average of values: 25.0

# %% [markdown]
# Question. 3 WAP to input a list of scores for N students in a list data type. Find the score of the runnerup and print the output.

# %%
n = int(input("Enter number of students: "))

scores = list(map(int, input("Enter scores: ").split()))

unique_scores = list(set(scores))

unique_scores.sort(reverse=True)

print("Runner-up score:", unique_scores[1])
# Out:
# Enter number of students: 2
# Enter scores: 20 30
# Runner-up score: 20

# %% [markdown]
# Question. 4 Create a dictionary of n persons where key is name and value is city

# %%
n = int(input("Enter number of persons: "))

persons = {}

for i in range(n):
    name = input("Enter name: ")
    city = input("Enter city: ")
    persons[name] = city

print("\nNames of all persons:")
for name in persons.keys():
    print(name)

print("\nCity names:")
for city in persons.values():
    print(city)

print("\nName and City of all persons:")
for name, city in persons.items():
    print(name, "->", city)

city_count = {}

for city in persons.values():
    city_count[city] = city_count.get(city, 0) + 1

print("\nNumber of students in each city:")
for city, count in city_count.items():
    print(city, ":", count)
# Out:
# Enter number of persons: 3
# Enter name: yash
# Enter city: haryana
# Enter name: abhinav
# Enter city: faridabad
# Enter name: siddhant
# Enter city: bihar
#
# Names of all persons:
# yash
# abhinav
# siddhant
#
# City names:
# haryana
# faridabad
# bihar
#
# Name and City of all persons:
# yash -> haryana
# abhinav -> faridabad
# siddhant -> bihar
#
# Number of students in each city:
# haryana : 1
# faridabad : 1
# bihar : 1

# %% [markdown]
# Question. 5 Store details of n movies in a dictionary by taking input from the user. Each movie must
# store details like name, year, director name, production cost, collection made (earning)
# & perform the following :-

# %%
n = int(input("Enter number of movies: "))

movies = {}

for i in range(n):
    print(f"\nEnter details for movie {i+1}:")
    name = input("Movie name: ")
    year = int(input("Year of release: "))
    director = input("Director name: ")
    cost = float(input("Production cost: "))
    collection = float(input("Collection made: "))

    movies[name] = {
        "Year": year,
        "Director": director,
        "Cost": cost,
        "Collection": collection
    }

print("\nAll movie details:")
for name, details in movies.items():
    print(f"\nMovie: {name}")
    for key, value in details.items():
        print(f"{key}: {value}")

print("\nMovies released before 2015:")
for name, details in movies.items():
    if details["Year"] < 2015:
        print(name)

print("\nMovies that made a profit:")
for name, details in movies.items():
    if details["Collection"] > details["Cost"]:
        print(name)

director_name = input("\nEnter director name to search: ")
print(f"Movies directed by {director_name}:")
for name, details in movies.items():
    if details["Director"].lower() == director_name.lower():
        print(name)
# Out:
# Enter number of movies: 2
#
# Enter details for movie 1:
# Movie name: sikandar
# Year of release: 2024
# Director name: ufv
# Production cost: 1000000000
# Collection made: 2000000000
#
# Enter details for movie 2:
# Movie name: dhudrandar
# Year of release: 2026
# Director name: fvva
# Production cost: 10000000
# Collection made: 30000000
#
# All movie details:
#
# Movie: sikandar
# Year: 2024
# Director: ufv
# Cost: 1000000000.0
# Collection: 2000000000.0
#
# Movie: dhudrandar
# Year: 2026
# Director: fvva
# Cost: 10000000.0
# Collection: 30000000.0
#
# Movies released before 2015:
#
# Movies that made a profit:
# sikandar
# dhudrandar
#
# Enter director name to search: ufv
# Movies directed by ufv:
# sikandar

# %% [markdown]
# Question. 6 Create a contact book where users can store, search, update, and delete contacts. Use
# dictionary for storing contacts.

# %%
contacts = {}

def add_contact():
    name = input("Enter contact name: ")
    phone = input("Enter phone number: ")
    contacts[name] = phone
    print(f"Contact {name} added successfully!")

def search_contact():
    name = input("Enter contact name to search: ")
    if name in contacts:
        print(f"{name}: {contacts[name]}")
    else:
        print("Contact not found.")

def update_contact():
    name = input("Enter contact name to update: ")
    if name in contacts:
        phone = input("Enter new phone number: ")
        contacts[name] = phone
        print(f"Contact {name} updated successfully!")
    else:
        print("Contact not found.")

def delete_contact():
    name = input("Enter contact name to delete: ")
    if name in contacts:
        del contacts[name]
        print(f"Contact {name} deleted successfully!")
    else:
        print("Contact not found.")

def display_contacts():
    if contacts:
        print("\nAll Contacts:")
        for name, phone in contacts.items():
            print(f"{name}: {phone}")
    else:
        print("No contacts available.")

while True:
    print("1. Add Contact")
    print("2. Search Contact")
    print("3. Update Contact")
    print("4. Delete Contact")
    print("5. Display All Contacts")
    print("6. Exit")

    choice = input("Enter your choice (1-6): ")

    if choice == "1":
        add_contact()
    elif choice == "2":
        search_contact()
    elif choice == "3":
        update_contact()
    elif choice == "4":
        delete_contact()
    elif choice == "5":
        display_contacts()
    elif choice == "6":
        print("Exiting Contact Book. Goodbye!")
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# 1. Add Contact
# 2. Search Contact
# 3. Update Contact
# 4. Delete Contact
# 5. Display All Contacts
# 6. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2146585311.py in <cell line: 0>()
#      47     print("6. Exit")
#      48
# ---> 49     choice = input("Enter your choice (1-6): ")
#      50
#      51     if choice == "1":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %% [markdown]
# Question.7 Create a Todo list Manager where users can add, view, and remove tasks. Use List for
# storing tasks.

# %%
tasks = []

def add_task():
    task = input("Enter a new task: ")
    tasks.append(task)
    print(f"Task '{task}' added successfully!")

def view_tasks():
    if tasks:
        print("\nYour Tasks:")
        for i, task in enumerate(tasks, start=1):
            print(f"{i}. {task}")
    else:
        print("No tasks available.")

def remove_task():
    if tasks:
        view_tasks()
        try:
            task_no = int(input("Enter the task number to remove: "))
            if 1 <= task_no <= len(tasks):
                removed = tasks.pop(task_no - 1)
                print(f"Task '{removed}' removed successfully!")
            else:
                print("Invalid task number.")
        except ValueError:
            print("Please enter a valid number.")
    else:
        print("No tasks to remove.")

while True:
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Remove Task")
    print("4. Exit")

    choice = input("Enter your choice (1-4): ")

    if choice == "1":
        add_task()
    elif choice == "2":
        view_tasks()
    elif choice == "3":
        remove_task()
    elif choice == "4":
        print("Exiting Todo List Manager. Goodbye!")
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice (1-4): 1
# Enter a new task: drink
# Task 'drink' added successfully!
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice (1-4): 2
#
# Your Tasks:
# 1. drink
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# Enter your choice (1-4): 1
# Enter a new task: t
# Task 't' added successfully!
# 1. Add Task
# 2. View Tasks
# 3. Remove Task
# 4. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2242349218.py in <cell line: 0>()
#      35     print("4. Exit")
#      36
# ---> 37     choice = input("Enter your choice (1-4): ")
#      38
#      39     if choice == "1":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
# ...
